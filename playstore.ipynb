# %% [markdown]
# <a href="https://colab.research.google.com/github/kollivarshini7625-cpu/IT-IGNITE/blob/main/playstore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
psd = pd.read_excel('playstore.csv.xlsx')
psd.head()
# Out:
#     App Name       Category  Rating  Reviews Downloads  Size_MB Price  \
# 0  Instagram   Social Media     4.5  1500000       5B+       75  Free
# 1   Facebook   Social Media     4.3  1800000       5B+       82  Free
# 2   WhatsApp  Communication     4.6  2200000       5B+       45  Free
# 3   Snapchat   Social Media     4.2   900000       1B+       65  Free
# 4  Twitter X   Social Media     4.1   850000       1B+       58  Free
#
#   Content Rating Platform
# 0           Teen  Android
# 1           Teen  Android
# 2       Everyone  Android
# 3           Teen  Android
# 4     Mature 17+  Android

# %%
psd.shape
# Out:
# (71, 9)

# %%
list(psd.columns)
# Out:
# ['App Name',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Downloads',
#  'Size_MB',
#  'Price',
#  'Content Rating',
#  'Platform']

# %%
psd.isnull().sum()
# Out:
# App Name          0
# Category          0
# Rating            0
# Reviews           0
# Downloads         0
# Size_MB           0
# Price             0
# Content Rating    0
# Platform          0
# dtype: int64

# %%
data = pd.read_excel('playstore.csv.xlsx')
print(data.head())
# Out:
#     App Name       Category  Rating  Reviews Downloads  Size_MB Price  \
# 0  Instagram   Social Media     4.5  1500000       5B+       75  Free
# 1   Facebook   Social Media     4.3  1800000       5B+       82  Free
# 2   WhatsApp  Communication     4.6  2200000       5B+       45  Free
# 3   Snapchat   Social Media     4.2   900000       1B+       65  Free
# 4  Twitter X   Social Media     4.1   850000       1B+       58  Free
#
#   Content Rating Platform
# 0           Teen  Android
# 1           Teen  Android
# 2       Everyone  Android
# 3           Teen  Android
# 4     Mature 17+  Android

# %%
import matplotlib.pyplot as plt

# %%
psd['Content Rating'].value_counts().plot.pie(fig =(7,15), autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
psd['Category'].value_counts().plot.pie(figsize=(10,10),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
psd['Category'].value_counts().plot.bar(figsize=(10,12),color ='r')
plt.ylabel('App Categories')
plt.xlabel('Number of apps')
plt.title('Number of apps in each category in playstore')
# Out:
# Text(0.5, 1.0, 'Number of apps in each category in playstore')
